# %%
import numpy as np

# %%
def ele_mul(inp,w):
    return [inp * weight for weight in w]

# %%
w = [0.4,0.5,0.6]

def nn(i,w):
    return ele_mul(i,w)

# %%
wlrec = [0.65, 0.8, 0.67]

input = wlrec[0]

pred = nn(input, w)

print(pred)
# Out:
# [0.26, 0.325, 0.39]
